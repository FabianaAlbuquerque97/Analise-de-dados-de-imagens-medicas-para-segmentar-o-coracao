# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
imagem = cv2.imread('/content/la_023.png')

# %%
imagem.shape
# Out:
# (320, 320, 3)

# %%
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=320x320>

# %%
linhas = imagem.shape[0]

# %%
linhas
# Out:
# 320

# %%
colunas = imagem.shape[1]

# %%
colunas
# Out:
# 320

# %%
linhas, colunas = imagem.shape[:2]

# %%
matriz_translacao=np.float32([[1,0,70],[0,1,110]])

# %%
imagem_translacao=cv2.warpAffine(imagem,matriz_translacao,(colunas,linhas),cv2.INTER_LINEAR)

# %%
cv2_imshow(imagem_translacao)
# Out:
# <PIL.Image.Image image mode=RGB size=320x320>
